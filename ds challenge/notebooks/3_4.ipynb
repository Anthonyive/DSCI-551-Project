# %% [markdown]
# # IMPORTS

# %%
import pandas as pd
import urllib
import socket
import time
from sqlalchemy import create_engine
import pymysql
start = time.time()

df_reddit_api = pd.read_csv('../data/Reddit_Api.csv')
df_praw = pd.read_csv('../data/PRAW.csv')

# %%
#df_reddit_api["image"]
local_dir = "../ds_images/"
streaming_idx = 0

for elem in df_reddit_api["image"]:
    if type(elem) == str:
        streaming_idx += 1 
        elem = elem.replace("amp;","")
        try:
            urllib.request.urlretrieve(elem,local_dir+str(streaming_idx)+'.jpg')
        except IOError as e:
            print(e)
# Out:
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found

# %%
user = "dsci551"
password = "Dsci-551"
host = "127.0.0.1"
database = "dsci551"
engine = create_engine("mysql+pymysql://user:pwd@localhost:3306")
#con = engine.connect()
PRAW_sql = df_praw.to_sql("PRAW",engine)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /opt/anaconda3/envs/PIP-551/lib/python3.8/site-packages/pymysql/connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# /opt/anaconda3/envs/PIP-551/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# /opt/anaconda3/envs/PIP-551/lib/python3.8/socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# ...
