# %% [markdown]
# # User Creation

# %% [markdown]
# Username: DSCI551 \
# Password: Dsci551

# %% [markdown]
# ```mysql
# mysql> CREATE USER 'DSCI551'@'localhost' IDENTIFIED BY 'Dsci551';
# mysql> GRANT ALL PRIVILEGES ON * . * TO 'DSCI551'@'localhost';
# mysql> FLUSH PRIVILEGES;
# ```
# Quit...then
# ```bash
# mysql -u DSCI551 -p
# ```

# %%
import sqlalchemy as db

# %%
engine = db.create_engine('mysql://DSCI551:Dsci551@localhost')

# %%
connection = engine.connect()
metadata = db.MetaData()

# %%
connection.execute("DROP DATABASE IF EXISTS Walmart;\
                CREATE DATABASE Walmart; \
                USE Walmart;")

# %% [markdown]
# # Download data

# %% [markdown]
# The data is in google drive here: https://drive.google.com/drive/folders/1WHRy07hECWWJGjJB1wPCvVXJxi-AQf3K?usp=sharing \
# Since there is currently no easy way of implementing download the data using python code, you should download the data yourself and put the entire 'data' folder into the current working directory's 'Downloads' folder.

# %%
import json, os

PATH = 'Downloads/data/'

# taxonomy data
with open(os.path.join(PATH, 'taxonomy.json'), 'r') as f:
    j = json.load(f)
    print(j['categories'])
# Out:
# [{'id': '1005862', 'name': 'Personal Care', 'path': 'Personal Care', 'children': [{'id': '1005862_1001487', 'name': 'Deodorants & Antiperspirants', 'path': 'Personal Care/Deodorants & Antiperspirants', 'children': []}, {'id': '1005862_1001508', 'name': 'Sun Care', 'path': 'Personal Care/Sun Care', 'children': [{'id': '1005862_1001508_2880849', 'name': 'Clean Living Sunscreen', 'path': 'Personal Care/Sun Care/Clean Living Sunscreen', 'children': []}, {'id': '1005862_1001508_5445092', 'name': 'Banana Boat Sunscreen', 'path': 'Personal Care/Sun Care/Banana Boat Sunscreen', 'children': []}, {'id': '1005862_1001508_5548238', 'name': 'Mineral Sunscreen', 'path': 'Personal Care/Sun Care/Mineral Sunscreen', 'children': []}, {'id': '1005862_1001508_6270511', 'name': 'Reef-Safe Sunscreen', 'path': 'Personal Care/Sun Care/Reef-Safe Sunscreen', 'children': []}, {'id': '1005862_1001508_6439038', 'name': 'Self-Tanners & Bronzers', 'path': 'Personal Care/Sun Care/Self-Tanners & Bronzers', 'children
# ...

# %%
j
# Out:
# dict_keys(['categories'])
